# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
print("Dataset with missing values")
print(df)
# Out:
# Dataset with missing values
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            NaN           0.2
# 1      2            NaN           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            NaN           0.2
# 4      5            5.0           NaN            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            NaN           3.4            5.4           2.3
# 149  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2               NaN
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

#Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

print("\nDataFrame after handling missing values:")
print(df)
# Out:
# DataFrame after handling missing values:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1       5.100000          3.50       3.778322           0.2
# 1      2       5.844521          3.00       1.400000           0.2
# 2      3       4.700000          3.20       1.300000           0.2
# 3      4       4.600000          3.10       3.778322           0.2
# 4      5       5.000000          3.05       1.400000           0.2
# ..   ...            ...           ...            ...           ...
# 145  146       6.700000          3.00       5.200000           2.3
# 146  147       6.300000          2.50       5.000000           1.9
# 147  148       6.500000          3.00       5.200000           2.0
# 148  149       5.844521          3.40       5.400000           2.3
# 149  150       5.900000          3.00       3.778322           1.8
#
#              Species
# 0        Iris-setosa
# 1        Iris-setosa
# 2    Iris-versicolor
# 3        Iris-setosa
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

#print("\nDataFrame after handling missing values:")
#print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

print("\nDataFrame after encoding categorical variables:")
print(df)
# Out:
# DataFrame after encoding categorical variables:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1       5.100000          3.50       3.778322           0.2        0
# 1      2       5.844521          3.00       1.400000           0.2        0
# 2      3       4.700000          3.20       1.300000           0.2        1
# 3      4       4.600000          3.10       3.778322           0.2        0
# 4      5       5.000000          3.05       1.400000           0.2        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146       6.700000          3.00       5.200000           2.3        1
# 146  147       6.300000          2.50       5.000000           1.9        2
# 147  148       6.500000          3.00       5.200000           2.0        2
# 148  149       5.844521          3.40       5.400000           2.3        2
# 149  150       5.900000          3.00       3.778322           1.8        2
#
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

#print("\nDataFrame after handling missing values:")
#print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

#print("\nDataFrame after encoding categorical variables:")
#print(df)

# 3. Feature Scaling

# Standardizing the features using StandardScaler
scaler = StandardScaler()
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

print("\nDataFrame after feature scaling:")
print(df)
# Out:
# DataFrame after feature scaling:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 0      1      -0.909755  1.057142e+00  -2.605498e-16     -1.331667        0
# 1      2       0.000000 -1.174602e-01  -1.395376e+00     -1.331667        0
# 2      3      -1.398528  3.523807e-01  -1.454046e+00     -1.331667        1
# 3      4      -1.520722  1.174602e-01  -2.605498e-16     -1.331667        0
# 4      5      -1.031948  1.043257e-15  -1.395376e+00     -1.331667        0
# ..   ...            ...           ...            ...           ...      ...
# 145  146       1.045339 -1.174602e-01   8.341072e-01      1.446065        1
# 146  147       0.556566 -1.292063e+00   7.167660e-01      0.916973        2
# 147  148       0.800953 -1.174602e-01   8.341072e-01      1.049246        2
# 148  149       0.000000  8.222217e-01   9.514485e-01      1.446065        2
# 149  150       0.067792 -1.174602e-01  -2.605498e-16      0.784700        2
#
# [150 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
print("Dataset with missing values")
print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

print("\nDataFrame after handling missing values:")
print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

print("\nDataFrame after encoding categorical variables:")
print(df)

# 3. Feature Scaling

# Standardizing the features using StandardScaler
scaler = StandardScaler()
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

print("\nDataFrame after feature scaling:")
print(df)
# Out:
# Dataset with missing values
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            NaN           0.2
# 1      2            NaN           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            NaN           0.2
# 4      5            5.0           NaN            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            NaN           3.4            5.4           2.3
# 149  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2               NaN
# 3       Iris-setosa
# 4       Iris-setosa
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

#print("\nDataFrame after handling missing values:")
#print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

#print("\nDataFrame after encoding categorical variables:")
#print(df)

# 3. Feature Scaling

# Standardizing the features using StandardScaler
#scaler = StandardScaler()
#df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

#print("\nDataFrame after feature scaling:")
#print(df)


# 4. Visualizing the distribution of a feature using a histogram
plt.figure(figsize=(5,3))
plt.hist(df['SepalLengthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Sepal Length")
plt.xlabel("Scaled Sepal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['SepalWidthCm'], bins=20, color='blue', edgecolor='black',alpha=0.7)
plt.title("Distribution of Scaled Sepal Width")
plt.xlabel("Scaled Sepal Width")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['PetalLengthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Petal Length")
plt.xlabel("Scaled Petal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['PetalWidthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Petal Width")
plt.xlabel("Scaled Petal Width")
plt.ylabel("Frequency")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

#print("\nDataFrame after handling missing values:")
#print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

#print("\nDataFrame after encoding categorical variables:")
#print(df)

# 3. Feature Scaling

# Standardizing the features using StandardScaler
#scaler = StandardScaler()
#df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

#print("\nDataFrame after feature scaling:")
#print(df)


# 5. Creating scatter plots to understand relationships between features
plt.figure(figsize=(8,5))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue=df['Species'], palette='Set2', data=df)
plt.title("Scatter Plot of Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (scaled)")
plt.ylabel("Sepal Width (scaled)")
plt.legend(title="Species")
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue=df['Species'], palette='Set2', data=df)
plt.title("Scatter Plot of Petal Length vs Petal Width")
plt.xlabel("Petal Length (scaled)")
plt.ylabel("Petal Width (scaled)")
plt.legend(title="Species")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer
import matplotlib.pyplot as plt
import seaborn as sns

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
#print("Dataset with missing values")
#print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

#print("\nDataFrame after handling missing values:")
#print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

#print("\nDataFrame after encoding categorical variables:")
#print(df)

# 3. Feature Scaling

# Standardizing the features using StandardScaler
#scaler = StandardScaler()
#df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

#print("\nDataFrame after feature scaling:")
#print(df)

# 6. Correlation heatmap
plt.figure(figsize=(8,5))
correlation_matrix = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder,StandardScaler
from sklearn.impute import SimpleImputer

#Printing dataset with missing values
iris_data = pd.read_csv("iris.csv")
df = pd.DataFrame(iris_data)
print("Dataset with missing values")
print(df)

# 1. Handling the missing values

# Using SimpleImputer to fill missing values with the mean for numerical columns
imputer_num = SimpleImputer(strategy='mean')
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=imputer_num.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])

# Handling missing values for categorical data using the most frequent value
imputer_cat = SimpleImputer(strategy='most_frequent')
df[['Species']]=imputer_cat.fit_transform(df[['Species']])

print("\nDataFrame after handling missing values:")
print(df)

# 2. Encoding Categorical Data

# Encoding 'Gender' and 'Country' using LabelEncoder
label_encoder = LabelEncoder()
df['Species']=label_encoder.fit_transform(df['Species'])

print("\nDataFrame after encoding categorical variables:")
print(df)

# 4. Visualizing the distribution of a feature using a histogram
plt.figure(figsize=(5,3))
plt.hist(df['SepalLengthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Sepal Length")
plt.xlabel("Scaled Sepal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['SepalWidthCm'], bins=20, color='blue', edgecolor='black',alpha=0.7)
plt.title("Distribution of Scaled Sepal Width")
plt.xlabel("Scaled Sepal Width")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['PetalLengthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Petal Length")
plt.xlabel("Scaled Petal Length")
plt.ylabel("Frequency")
plt.show()

plt.figure(figsize=(5,3))
plt.hist(df['PetalWidthCm'], bins=20, color='blue', edgecolor='black', alpha=0.7)
plt.title("Distribution of Scaled Petal Width")
plt.xlabel("Scaled Petal Width")
plt.ylabel("Frequency")
plt.show()

# 5. Creating scatter plots to understand relationships between features
plt.figure(figsize=(8,5))
sns.scatterplot(x='SepalLengthCm', y='SepalWidthCm', hue=df['Species'], palette='Set2', data=df)
plt.title("Scatter Plot of Sepal Length vs Sepal Width")
plt.xlabel("Sepal Length (scaled)")
plt.ylabel("Sepal Width (scaled)")
plt.legend(title="Species")
plt.show()

plt.figure(figsize=(8, 5))
sns.scatterplot(x='PetalLengthCm', y='PetalWidthCm', hue=df['Species'], palette='Set2', data=df)
plt.title("Scatter Plot of Petal Length vs Petal Width")
plt.xlabel("Petal Length (scaled)")
plt.ylabel("Petal Width (scaled)")
plt.legend(title="Species")
plt.show()

# 6. Correlation heatmap
plt.figure(figsize=(8,5))
correlation_matrix = df[['SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()


# 3. Feature Scaling
# Standardizing the features using StandardScaler
scaler = StandardScaler()
df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']]=scaler.fit_transform(df[['SepalLengthCm','SepalWidthCm','PetalLengthCm','PetalWidthCm']])
print("\nDataFrame after feature scaling:")
print(df)
# Out:
# Dataset with missing values
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            NaN           0.2
# 1      2            NaN           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            NaN           0.2
# 4      5            5.0           NaN            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            NaN           3.4            5.4           2.3
# 149  150            5.9           3.0            NaN           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2               NaN
# 3       Iris-setosa
# 4       Iris-setosa
# ...
